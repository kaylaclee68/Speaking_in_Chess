# %%
import chess
from tokenizers import (
    decoders,
    models,
    normalizers,
    pre_tokenizers,
    processors,
    trainers,
    Tokenizer,
)
import tqdm
from chess import Board

# %%
board = Board()
moves = set()
turn = chess.WHITE
for piece_type in chess.PIECE_TYPES:
    if piece_type != chess.PAWN:
        piece = chess.Piece(piece_type, turn)
        for i in range(64):
            board.set_piece_map({i: piece})
            board.turn = turn
            for move in board.generate_pseudo_legal_moves():
                moves.add(board.lan(move))

# %%
len(moves)
# Out:
# 3668

# %%
board = Board()
pawn_moves = set()
turn = chess.WHITE
turn2 = chess.BLACK

piece = chess.Piece(chess.PAWN, turn)
for i in range(8,56, 8):
    board.set_piece_map(dict((j, piece) for j in range(i, i+8)))
    board.turn = turn
    #display(board)
    for move in board.generate_pseudo_legal_moves():
        pawn_moves.add(board.lan(move))

piece2 = chess.Piece(chess.ROOK, turn2)
for i in range(8,56, 8):
    board.set_piece_map(dict((j, piece) for j in range(i, i+8)) | dict((j, piece2) for j in range(i+8, i+16)))
    board.turn = turn
    #display(board)
    for move in board.generate_pseudo_legal_moves():
        pawn_moves.add(board.lan(move))

piece = chess.Piece(chess.PAWN, turn2)
for i in range(8,56, 8):
    board.set_piece_map(dict((j, piece) for j in range(i, i+8)))
    board.turn = turn2
    #display(board)
    for move in board.generate_pseudo_legal_moves():
        pawn_moves.add(board.lan(move))

piece2 = chess.Piece(chess.ROOK, turn)
for i in range(0,48, 8):
    board.set_piece_map(dict((j, piece2) for j in range(i, i+8)) | dict((j, piece) for j in range(i+8, i+16)))
    board.turn = turn2
    #display(board)
    for move in board.generate_pseudo_legal_moves():
        pawn_moves.add(board.lan(move))

# %%
len(pawn_moves)
# Out:
# 412

# %%
all_moves = list()
takes = ['-', 'x']
specials = ['', '+', "#"]
for move in moves:
    for take in takes:
        for special in specials:
            all_moves.append(move.replace("-", take) + special)

for move in pawn_moves:
    for special in specials:
        all_moves.append(move + special)

castles = ['O-O', 'O-O+', 'O-O#', 'O-O-O', 'O-O-O+', 'O-O-O#']
all_moves += castles

# %%
all_moves
# Out:
# ['Nc8-d6',
#  'Nc8-d6+',
#  'Nc8-d6#',
#  'Nc8xd6',
#  'Nc8xd6+',
#  'Nc8xd6#',
#  'Ra8-b8',
#  'Ra8-b8+',
#  'Ra8-b8#',
#  'Ra8xb8',
#  'Ra8xb8+',
#  'Ra8xb8#',
#  'Rh1-h8',
#  'Rh1-h8+',
#  'Rh1-h8#',
#  'Rh1xh8',
#  'Rh1xh8+',
#  'Rh1xh8#',
#  'Re3-e7',
#  'Re3-e7+',
#  'Re3-e7#',
#  'Re3xe7',
#  'Re3xe7+',
#  'Re3xe7#',
#  'Rb7-b2',
#  'Rb7-b2+',
#  'Rb7-b2#',
#  'Rb7xb2',
#  'Rb7xb2+',
#  'Rb7xb2#',
#  'Ng7-f5',
#  'Ng7-f5+',
#  'Ng7-f5#',
#  'Ng7xf5',
#  'Ng7xf5+',
#  'Ng7xf5#',
#  'Qb2-b1',
#  'Qb2-b1+',
#  'Qb2-b1#',
#  'Qb2xb1',
#  'Qb2xb1+',
#  'Qb2xb1#',
#  'Qc5-d5',
#  'Qc5-d5+',
#  'Qc5-d5#',
#  'Qc5xd5',
#  'Qc5xd5+',
#  'Qc5xd5#',
#  'Qb5-b2',
#  'Qb5-b2+',
#  'Qb5-b2#',
#  'Qb5xb2',
#  'Qb5xb2+',
#  'Qb5xb2#',
#  'Qb7-e7',
#  'Qb7-e7+',
#  'Qb7-e7#',
#  'Qb7xe7',
#  'Qb7xe7+',
#  'Qb7xe7#',
#  'Qh7-h5',
#  'Qh7-h5+',
#  'Qh7-h5#',
#  'Qh7xh5',
#  'Qh7xh5+',
#  'Qh7xh5#',
#  'Ke4-f4',
#  'Ke4-f4+',
#  'Ke4-f4#',
#  'Ke4xf4',
#  'Ke4xf4+',
#  'Ke4xf4#',
#  'Qb1-h7',
#  'Qb1-h7+',
#  'Qb1-h7#',
#  'Qb1xh7',
#  'Qb1xh7+',
#  'Qb1xh7#',
#  'Kb5-c6',
#  'Kb5-c6+',
#  'Kb5-c6#',
#  'Kb5xc6',
#  'Kb5xc6+',
#  'Kb5xc6#',
#  'Kg4-f4',
#  'Kg4-f4+',
#  'Kg4-f4#',
#  'Kg4xf4',
#  'Kg4xf4+',
#  'Kg4xf4#',
#  'Qh7-f5',
#  'Qh7-f5+',
#  'Qh7-f5#',
#  'Qh7xf5',
#  'Qh7xf5+',
#  'Qh7xf5#',
#  'Ke4-d3',
#  'Ke4-d3+',
#  'Ke4-d3#',
#  'Ke4xd3',
#  'Ke4xd3+',
#  'Ke4xd3#',
#  'Ra1-b1',
#  'Ra1-b1+',
#  'Ra1-b1#',
#  'Ra1xb1',
#  'Ra1xb1+',
#  'Ra1xb1#',
#  'Kc5-b5',
#  'Kc5-b5+',
#  'Kc5-b5#',
#  'Kc5xb5',
#  'Kc5xb5+',
#  'Kc5xb5#',
#  'Qg1-g5',
#  'Qg1-g5+',
#  'Qg1-g5#',
#  'Qg1xg5',
#  'Qg1xg5+',
#  'Qg1xg5#',
#  'Kc4-b5',
#  'Kc4-b5+',
#  'Kc4-b5#',
#  'Kc4xb5',
#  'Kc4xb5+',
#  'Kc4xb5#',
#  'Nh1-g3',
#  'Nh1-g3+',
#  'Nh1-g3#',
#  'Nh1xg3',
#  'Nh1xg3+',
#  'Nh1xg3#',
#  'Qa4-h4',
#  'Qa4-h4+',
#  'Qa4-h4#',
#  'Qa4xh4',
#  'Qa4xh4+',
#  'Qa4xh4#',
#  'Qf8-f4',
#  'Qf8-f4+',
#  'Qf8-f4#',
#  'Qf8xf4',
#  'Qf8xf4+',
#  'Qf8xf4#',
#  'Qd2-d5',
#  'Qd2-d5+',
#  'Qd2-d5#',
#  'Qd2xd5',
#  'Qd2xd5+',
#  'Qd2xd5#',
#  'Qf2-f5',
#  'Qf2-f5+',
#  'Qf2-f5#',
#  'Qf2xf5',
#  'Qf2xf5+',
#  'Qf2xf5#',
#  'Kf4-g4',
#  'Kf4-g4+',
#  'Kf4-g4#',
#  'Kf4xg4',
#  'Kf4xg4+',
#  'Kf4xg4#',
#  'Kf7-g8',
#  'Kf7-g8+',
#  'Kf7-g8#',
#  'Kf7xg8',
#  'Kf7xg8+',
#  'Kf7xg8#',
#  'Rg5-e5',
#  'Rg5-e5+',
#  'Rg5-e5#',
#  'Rg5xe5',
#  'Rg5xe5+',
#  'Rg5xe5#',
#  'Qd5-f3',
#  'Qd5-f3+',
#  'Qd5-f3#',
#  'Qd5xf3',
#  'Qd5xf3+',
#  'Qd5xf3#',
#  'Rd5-c5',
#  'Rd5-c5+',
#  'Rd5-c5#',
#  'Rd5xc5',
#  'Rd5xc5+',
#  'Rd5xc5#',
#  'Qc6-c7',
#  'Qc6-c7+',
#  'Qc6-c7#',
#  'Qc6xc7',
#  'Qc6xc7+',
#  'Qc6xc7#',
#  'Ba2-d5',
#  'Ba2-d5+',
#  'Ba2-d5#',
#  'Ba2xd5',
#  'Ba2xd5+',
#  'Ba2xd5#',
#  'Qe7-g5',
#  'Qe7-g5+',
#  'Qe7-g5#',
#  'Qe7xg5',
#  'Qe7xg5+',
#  'Qe7xg5#',
#  'Qg2-g6',
#  'Qg2-g6+',
#  'Qg2-g6#',
#  'Qg2xg6',
#  'Qg2xg6+',
#  'Qg2xg6#',
#  'Bf2-e1',
#  'Bf2-e1+',
#  'Bf2-e1#',
#  'Bf2xe1',
#  'Bf2xe1+',
#  'Bf2xe1#',
#  'Qg8-a8',
#  'Qg8-a8+',
#  'Qg8-a8#',
#  'Qg8xa8',
#  'Qg8xa8+',
#  'Qg8xa8#',
#  'Ka8-a7',
#  'Ka8-a7+',
#  'Ka8-a7#',
#  'Ka8xa7',
#  'Ka8xa7+',
#  'Ka8xa7#',
#  'Re7-e2',
#  'Re7-e2+',
#  'Re7-e2#',
#  'Re7xe2',
#  'Re7xe2+',
#  'Re7xe2#',
#  'Qg8-h7',
#  'Qg8-h7+',
#  'Qg8-h7#',
#  'Qg8xh7',
#  'Qg8xh7+',
#  'Qg8xh7#',
#  'Rd4-h4',
#  'Rd4-h4+',
#  'Rd4-h4#',
#  'Rd4xh4',
#  'Rd4xh4+',
#  'Rd4xh4#',
#  'Na5-b3',
#  'Na5-b3+',
#  'Na5-b3#',
#  'Na5xb3',
#  'Na5xb3+',
#  'Na5xb3#',
#  'Qd6-e6',
#  'Qd6-e6+',
#  'Qd6-e6#',
#  'Qd6xe6',
#  'Qd6xe6+',
#  'Qd6xe6#',
#  'Ne5-f3',
#  'Ne5-f3+',
#  'Ne5-f3#',
#  'Ne5xf3',
#  'Ne5xf3+',
#  'Ne5xf3#',
#  'Qh1-h7',
#  'Qh1-h7+',
#  'Qh1-h7#',
#  'Qh1xh7',
#  'Qh1xh7+',
#  'Qh1xh7#',
#  'Rd1-b1',
#  'Rd1-b1+',
#  'Rd1-b1#',
#  'Rd1xb1',
#  'Rd1xb1+',
#  'Rd1xb1#',
#  'Qb4-e4',
#  'Qb4-e4+',
#  'Qb4-e4#',
#  'Qb4xe4',
#  'Qb4xe4+',
#  'Qb4xe4#',
#  'Qc2-f5',
#  'Qc2-f5+',
#  'Qc2-f5#',
#  'Qc2xf5',
#  'Qc2xf5+',
#  'Qc2xf5#',
#  'Nc4-d2',
#  'Nc4-d2+',
#  'Nc4-d2#',
#  'Nc4xd2',
#  'Nc4xd2+',
#  'Nc4xd2#',
#  'Ra7-a8',
#  'Ra7-a8+',
#  'Ra7-a8#',
#  'Ra7xa8',
#  'Ra7xa8+',
#  'Ra7xa8#',
#  'Qg3-g1',
#  'Qg3-g1+',
#  'Qg3-g1#',
#  'Qg3xg1',
#  'Qg3xg1+',
#  'Qg3xg1#',
#  'Qc5-f2',
#  'Qc5-f2+',
#  'Qc5-f2#',
#  'Qc5xf2',
#  'Qc5xf2+',
#  'Qc5xf2#',
#  'Re1-a1',
#  'Re1-a1+',
#  'Re1-a1#',
#  'Re1xa1',
#  'Re1xa1+',
#  'Re1xa1#',
#  'Ng4-f6',
#  'Ng4-f6+',
#  'Ng4-f6#',
#  'Ng4xf6',
#  'Ng4xf6+',
#  'Ng4xf6#',
#  'Re2-e5',
#  'Re2-e5+',
#  'Re2-e5#',
#  'Re2xe5',
#  'Re2xe5+',
#  'Re2xe5#',
#  'Bd5-a2',
#  'Bd5-a2+',
#  'Bd5-a2#',
#  'Bd5xa2',
#  'Bd5xa2+',
#  'Bd5xa2#',
#  'Ke7-d6',
#  'Ke7-d6+',
#  'Ke7-d6#',
#  'Ke7xd6',
#  'Ke7xd6+',
#  'Ke7xd6#',
#  'Qg2-f1',
#  'Qg2-f1+',
#  'Qg2-f1#',
#  'Qg2xf1',
#  'Qg2xf1+',
#  'Qg2xf1#',
#  'Qa5-b5',
#  'Qa5-b5+',
#  'Qa5-b5#',
#  'Qa5xb5',
#  'Qa5xb5+',
#  'Qa5xb5#',
#  'Qh6-h1',
#  'Qh6-h1+',
#  'Qh6-h1#',
#  'Qh6xh1',
#  'Qh6xh1+',
#  'Qh6xh1#',
#  'Rd4-g4',
#  'Rd4-g4+',
#  'Rd4-g4#',
#  'Rd4xg4',
#  'Rd4xg4+',
#  'Rd4xg4#',
#  'Qg5-f5',
#  'Qg5-f5+',
#  'Qg5-f5#',
#  'Qg5xf5',
#  'Qg5xf5+',
#  'Qg5xf5#',
#  'Nb4-a2',
#  'Nb4-a2+',
#  'Nb4-a2#',
#  'Nb4xa2',
#  'Nb4xa2+',
#  'Nb4xa2#',
#  'Qa5-h5',
#  'Qa5-h5+',
#  'Qa5-h5#',
#  'Qa5xh5',
#  'Qa5xh5+',
#  'Qa5xh5#',
#  'Qc5-d4',
#  'Qc5-d4+',
#  'Qc5-d4#',
#  'Qc5xd4',
#  'Qc5xd4+',
#  'Qc5xd4#',
#  'Bf1-e2',
#  'Bf1-e2+',
#  'Bf1-e2#',
#  'Bf1xe2',
#  'Bf1xe2+',
#  'Bf1xe2#',
#  'Nb3-c5',
#  'Nb3-c5+',
#  'Nb3-c5#',
#  'Nb3xc5',
#  'Nb3xc5+',
#  'Nb3xc5#',
#  'Kg4-h3',
#  'Kg4-h3+',
#  'Kg4-h3#',
#  'Kg4xh3',
#  'Kg4xh3+',
#  'Kg4xh3#',
#  'Kc4-d5',
#  'Kc4-d5+',
#  'Kc4-d5#',
#  'Kc4xd5',
#  'Kc4xd5+',
#  'Kc4xd5#',
#  'Rg5-g1',
#  'Rg5-g1+',
#  'Rg5-g1#',
#  'Rg5xg1',
#  'Rg5xg1+',
#  'Rg5xg1#',
#  'Qg1-g2',
#  'Qg1-g2+',
#  'Qg1-g2#',
#  'Qg1xg2',
#  'Qg1xg2+',
#  'Qg1xg2#',
#  'Qd4-a7',
#  'Qd4-a7+',
#  'Qd4-a7#',
#  'Qd4xa7',
#  'Qd4xa7+',
#  'Qd4xa7#',
#  'Bf2-a7',
#  'Bf2-a7+',
#  'Bf2-a7#',
#  'Bf2xa7',
#  'Bf2xa7+',
#  'Bf2xa7#',
#  'Qc3-c1',
#  'Qc3-c1+',
#  'Qc3-c1#',
#  'Qc3xc1',
#  'Qc3xc1+',
#  'Qc3xc1#',
#  'Qh4-e4',
#  'Qh4-e4+',
#  'Qh4-e4#',
#  'Qh4xe4',
#  'Qh4xe4+',
#  'Qh4xe4#',
#  'Qh2-h3',
#  'Qh2-h3+',
#  'Qh2-h3#',
#  'Qh2xh3',
#  'Qh2xh3+',
#  'Qh2xh3#',
#  'Nb6-a4',
#  'Nb6-a4+',
#  'Nb6-a4#',
#  'Nb6xa4',
#  'Nb6xa4+',
#  'Nb6xa4#',
#  'Bf1-g2',
#  'Bf1-g2+',
#  'Bf1-g2#',
#  'Bf1xg2',
#  'Bf1xg2+',
#  'Bf1xg2#',
#  'Rb1-g1',
#  'Rb1-g1+',
#  'Rb1-g1#',
#  'Rb1xg1',
#  'Rb1xg1+',
#  'Rb1xg1#',
#  'Bd8-g5',
#  'Bd8-g5+',
#  'Bd8-g5#',
#  'Bd8xg5',
#  'Bd8xg5+',
#  'Bd8xg5#',
#  'Qa1-d1',
#  'Qa1-d1+',
#  'Qa1-d1#',
#  'Qa1xd1',
#  'Qa1xd1+',
#  'Qa1xd1#',
#  'Rd4-c4',
#  'Rd4-c4+',
#  'Rd4-c4#',
#  'Rd4xc4',
#  'Rd4xc4+',
#  'Rd4xc4#',
#  'Qf1-f7',
#  'Qf1-f7+',
#  'Qf1-f7#',
#  'Qf1xf7',
#  'Qf1xf7+',
#  'Qf1xf7#',
#  'Qf1-a6',
#  'Qf1-a6+',
#  'Qf1-a6#',
#  'Qf1xa6',
#  'Qf1xa6+',
#  'Qf1xa6#',
#  'Kd5-c6',
#  'Kd5-c6+',
#  'Kd5-c6#',
#  'Kd5xc6',
#  'Kd5xc6+',
#  'Kd5xc6#',
#  'Ra2-a3',
#  'Ra2-a3+',
#  'Ra2-a3#',
#  'Ra2xa3',
#  'Ra2xa3+',
#  'Ra2xa3#',
#  'Kd7-c8',
#  'Kd7-c8+',
#  'Kd7-c8#',
#  'Kd7xc8',
#  'Kd7xc8+',
#  'Kd7xc8#',
#  'Qc8-c5',
#  'Qc8-c5+',
#  'Qc8-c5#',
#  'Qc8xc5',
#  'Qc8xc5+',
#  'Qc8xc5#',
#  'Nd1-f2',
#  'Nd1-f2+',
#  'Nd1-f2#',
#  'Nd1xf2',
#  'Nd1xf2+',
#  'Nd1xf2#',
#  'Rf1-a1',
#  'Rf1-a1+',
#  'Rf1-a1#',
#  'Rf1xa1',
#  'Rf1xa1+',
#  'Rf1xa1#',
#  'Ke7-d8',
#  'Ke7-d8+',
#  'Ke7-d8#',
#  'Ke7xd8',
#  'Ke7xd8+',
#  'Ke7xd8#',
#  'Qf5-g5',
#  'Qf5-g5+',
#  'Qf5-g5#',
#  'Qf5xg5',
#  'Qf5xg5+',
#  'Qf5xg5#',
#  'Qa7-d4',
#  'Qa7-d4+',
#  'Qa7-d4#',
#  'Qa7xd4',
#  'Qa7xd4+',
#  'Qa7xd4#',
#  'Na7-b5',
#  'Na7-b5+',
#  'Na7-b5#',
#  'Na7xb5',
#  'Na7xb5+',
#  'Na7xb5#',
#  'Re5-f5',
#  'Re5-f5+',
#  'Re5-f5#',
#  'Re5xf5',
#  'Re5xf5+',
#  'Re5xf5#',
#  'Kg8-f7',
#  'Kg8-f7+',
#  'Kg8-f7#',
#  'Kg8xf7',
#  'Kg8xf7+',
#  'Kg8xf7#',
#  'Bh2-g1',
#  'Bh2-g1+',
#  'Bh2-g1#',
#  'Bh2xg1',
#  'Bh2xg1+',
#  'Bh2xg1#',
#  'Qa5-a2',
#  'Qa5-a2+',
#  'Qa5-a2#',
#  'Qa5xa2',
#  'Qa5xa2+',
#  'Qa5xa2#',
#  'Kf3-e3',
#  'Kf3-e3+',
#  'Kf3-e3#',
#  'Kf3xe3',
#  'Kf3xe3+',
#  'Kf3xe3#',
#  'Re4-e5',
#  'Re4-e5+',
#  'Re4-e5#',
#  'Re4xe5',
#  'Re4xe5+',
#  'Re4xe5#',
#  'Qe4-c6',
#  'Qe4-c6+',
#  'Qe4-c6#',
#  'Qe4xc6',
#  'Qe4xc6+',
#  'Qe4xc6#',
#  'Qh7-d7',
#  'Qh7-d7+',
#  'Qh7-d7#',
#  'Qh7xd7',
#  'Qh7xd7+',
#  'Qh7xd7#',
#  'Rh2-d2',
#  'Rh2-d2+',
#  'Rh2-d2#',
#  'Rh2xd2',
#  'Rh2xd2+',
#  'Rh2xd2#',
#  'Ra3-a4',
#  'Ra3-a4+',
#  'Ra3-a4#',
#  'Ra3xa4',
#  'Ra3xa4+',
#  'Ra3xa4#',
#  'Qc1-h1',
#  'Qc1-h1+',
#  'Qc1-h1#',
#  'Qc1xh1',
#  'Qc1xh1+',
#  'Qc1xh1#',
#  'Qd3-c4',
#  'Qd3-c4+',
#  'Qd3-c4#',
#  'Qd3xc4',
#  'Qd3xc4+',
#  'Qd3xc4#',
#  'Qh3-a3',
#  'Qh3-a3+',
#  'Qh3-a3#',
#  'Qh3xa3',
#  'Qh3xa3+',
#  'Qh3xa3#',
#  'Qh3-h1',
#  'Qh3-h1+',
#  'Qh3-h1#',
#  'Qh3xh1',
#  'Qh3xh1+',
#  'Qh3xh1#',
#  'Ra3-a1',
#  'Ra3-a1+',
#  'Ra3-a1#',
#  'Ra3xa1',
#  'Ra3xa1+',
#  'Ra3xa1#',
#  'Be2-h5',
#  'Be2-h5+',
#  'Be2-h5#',
#  'Be2xh5',
#  'Be2xh5+',
#  'Be2xh5#',
#  'Nf4-h5',
#  'Nf4-h5+',
#  'Nf4-h5#',
#  'Nf4xh5',
#  'Nf4xh5+',
#  'Nf4xh5#',
#  'Re4-d4',
#  'Re4-d4+',
#  'Re4-d4#',
#  'Re4xd4',
#  'Re4xd4+',
#  'Re4xd4#',
#  'Rf2-f3',
#  'Rf2-f3+',
#  'Rf2-f3#',
#  'Rf2xf3',
#  'Rf2xf3+',
#  'Rf2xf3#',
#  'Qg5-a5',
#  'Qg5-a5+',
#  'Qg5-a5#',
#  'Qg5xa5',
#  'Qg5xa5+',
#  'Qg5xa5#',
#  'Qg2-e4',
#  'Qg2-e4+',
#  'Qg2-e4#',
#  'Qg2xe4',
#  'Qg2xe4+',
#  'Qg2xe4#',
#  'Ra8-c8',
#  'Ra8-c8+',
#  'Ra8-c8#',
#  'Ra8xc8',
#  'Ra8xc8+',
#  'Ra8xc8#',
#  'Kd4-e5',
#  'Kd4-e5+',
#  'Kd4-e5#',
#  'Kd4xe5',
#  'Kd4xe5+',
#  'Kd4xe5#',
#  'Qc6-c1',
#  'Qc6-c1+',
#  'Qc6-c1#',
#  'Qc6xc1',
#  'Qc6xc1+',
#  'Qc6xc1#',
#  'Qb6-b2',
#  'Qb6-b2+',
#  'Qb6-b2#',
#  'Qb6xb2',
#  'Qb6xb2+',
#  'Qb6xb2#',
#  'Rh7-h6',
#  'Rh7-h6+',
#  'Rh7-h6#',
#  'Rh7xh6',
#  'Rh7xh6+',
#  'Rh7xh6#',
#  'Qb4-b3',
#  'Qb4-b3+',
#  'Qb4-b3#',
#  'Qb4xb3',
#  'Qb4xb3+',
#  'Qb4xb3#',
#  'Ka3-a4',
#  'Ka3-a4+',
#  'Ka3-a4#',
#  'Ka3xa4',
#  'Ka3xa4+',
#  'Ka3xa4#',
#  'Ng5-h3',
#  'Ng5-h3+',
#  'Ng5-h3#',
#  'Ng5xh3',
#  'Ng5xh3+',
#  'Ng5xh3#',
#  'Kg8-f8',
#  'Kg8-f8+',
#  'Kg8-f8#',
#  'Kg8xf8',
#  'Kg8xf8+',
#  'Kg8xf8#',
#  'Qh5-h4',
#  'Qh5-h4+',
#  'Qh5-h4#',
#  'Qh5xh4',
#  'Qh5xh4+',
#  'Qh5xh4#',
#  'Bd4-f6',
#  'Bd4-f6+',
#  'Bd4-f6#',
#  'Bd4xf6',
#  'Bd4xf6+',
#  'Bd4xf6#',
#  'Rg6-c6',
#  'Rg6-c6+',
#  'Rg6-c6#',
#  'Rg6xc6',
#  'Rg6xc6+',
#  'Rg6xc6#',
#  'Qa4-c4',
#  'Qa4-c4+',
#  'Qa4-c4#',
#  'Qa4xc4',
#  'Qa4xc4+',
#  'Qa4xc4#',
#  'Qd3-d2',
#  'Qd3-d2+',
#  'Qd3-d2#',
#  'Qd3xd2',
#  'Qd3xd2+',
#  'Qd3xd2#',
#  'Kg8-h7',
#  'Kg8-h7+',
#  'Kg8-h7#',
#  'Kg8xh7',
#  'Kg8xh7+',
#  'Kg8xh7#',
#  'Kh6-g7',
#  'Kh6-g7+',
#  'Kh6-g7#',
#  'Kh6xg7',
#  'Kh6xg7+',
#  'Kh6xg7#',
#  'Kg5-h4',
#  'Kg5-h4+',
#  'Kg5-h4#',
#  'Kg5xh4',
#  'Kg5xh4+',
#  'Kg5xh4#',
#  'Qe2-g4',
#  'Qe2-g4+',
#  'Qe2-g4#',
#  'Qe2xg4',
#  'Qe2xg4+',
#  'Qe2xg4#',
#  'Rd2-d4',
#  'Rd2-d4+',
#  'Rd2-d4#',
#  'Rd2xd4',
#  'Rd2xd4+',
#  'Rd2xd4#',
#  'Qc6-h1',
#  'Qc6-h1+',
#  'Qc6-h1#',
#  'Qc6xh1',
#  'Qc6xh1+',
#  'Qc6xh1#',
#  'Re2-h2',
#  'Re2-h2+',
#  'Re2-h2#',
#  'Re2xh2',
#  'Re2xh2+',
#  'Re2xh2#',
#  'Qe4-c2',
#  'Qe4-c2+',
#  'Qe4-c2#',
#  'Qe4xc2',
#  'Qe4xc2+',
#  'Qe4xc2#',
#  'Qa2-a3',
#  'Qa2-a3+',
#  'Qa2-a3#',
#  'Qa2xa3',
#  'Qa2xa3+',
#  'Qa2xa3#',
#  'Qh6-c1',
#  'Qh6-c1+',
#  'Qh6-c1#',
#  'Qh6xc1',
#  'Qh6xc1+',
#  'Qh6xc1#',
#  'Qg4-g7',
#  'Qg4-g7+',
#  'Qg4-g7#',
#  'Qg4xg7',
#  'Qg4xg7+',
#  'Qg4xg7#',
#  'Qg3-f2',
#  'Qg3-f2+',
#  'Qg3-f2#',
#  'Qg3xf2',
#  'Qg3xf2+',
#  'Qg3xf2#',
#  'Ne6-f4',
#  'Ne6-f4+',
#  'Ne6-f4#',
#  'Ne6xf4',
#  'Ne6xf4+',
#  'Ne6xf4#',
#  'Ng3-h5',
#  'Ng3-h5+',
#  'Ng3-h5#',
#  'Ng3xh5',
#  'Ng3xh5+',
#  'Ng3xh5#',
#  'Be3-b6',
#  'Be3-b6+',
#  'Be3-b6#',
#  'Be3xb6',
#  'Be3xb6+',
#  'Be3xb6#',
#  'Qh4-h6',
#  'Qh4-h6+',
#  'Qh4-h6#',
#  'Qh4xh6',
#  'Qh4xh6+',
#  'Qh4xh6#',
#  'Ng2-e1',
#  'Ng2-e1+',
#  'Ng2-e1#',
#  'Ng2xe1',
#  'Ng2xe1+',
#  'Ng2xe1#',
#  'Qh1-h6',
#  'Qh1-h6+',
#  'Qh1-h6#',
#  'Qh1xh6',
#  'Qh1xh6+',
#  'Qh1xh6#',
#  'Rf3-f6',
#  'Rf3-f6+',
#  'Rf3-f6#',
#  'Rf3xf6',
#  'Rf3xf6+',
#  'Rf3xf6#',
#  'Ra5-a3',
#  'Ra5-a3+',
#  'Ra5-a3#',
#  'Ra5xa3',
#  'Ra5xa3+',
#  'Ra5xa3#',
#  'Qg1-b1',
#  'Qg1-b1+',
#  'Qg1-b1#',
#  'Qg1xb1',
#  'Qg1xb1+',
#  'Qg1xb1#',
#  'Ke6-e7',
#  'Ke6-e7+',
#  'Ke6-e7#',
#  'Ke6xe7',
#  'Ke6xe7+',
#  'Ke6xe7#',
#  'Rf7-h7',
#  'Rf7-h7+',
#  'Rf7-h7#',
#  'Rf7xh7',
#  'Rf7xh7+',
#  'Rf7xh7#',
#  'Re8-e5',
#  'Re8-e5+',
#  'Re8-e5#',
#  'Re8xe5',
#  'Re8xe5+',
#  'Re8xe5#',
#  'Qe5-b8',
#  'Qe5-b8+',
#  'Qe5-b8#',
#  'Qe5xb8',
#  'Qe5xb8+',
#  'Qe5xb8#',
#  'Qc1-c3',
#  'Qc1-c3+',
#  'Qc1-c3#',
#  'Qc1xc3',
#  'Qc1xc3+',
#  'Qc1xc3#',
#  'Qf8-d8',
#  'Qf8-d8+',
#  'Qf8-d8#',
#  'Qf8xd8',
#  'Qf8xd8+',
#  'Qf8xd8#',
#  'Qc1-b1',
#  'Qc1-b1+',
#  'Qc1-b1#',
#  'Qc1xb1',
#  'Qc1xb1+',
#  'Qc1xb1#',
#  'Kd1-e1',
#  'Kd1-e1+',
#  'Kd1-e1#',
#  'Kd1xe1',
#  'Kd1xe1+',
#  'Kd1xe1#',
#  'Kh4-h3',
#  'Kh4-h3+',
#  'Kh4-h3#',
#  'Kh4xh3',
#  'Kh4xh3+',
#  'Kh4xh3#',
#  'Ka2-b2',
#  'Ka2-b2+',
#  'Ka2-b2#',
#  'Ka2xb2',
#  'Ka2xb2+',
#  'Ka2xb2#',
#  'Qe8-h5',
#  'Qe8-h5+',
#  'Qe8-h5#',
#  'Qe8xh5',
#  'Qe8xh5+',
#  'Qe8xh5#',
#  'Qc1-c5',
#  'Qc1-c5+',
#  'Qc1-c5#',
#  'Qc1xc5',
#  'Qc1xc5+',
#  'Qc1xc5#',
#  'Qb5-d5',
#  'Qb5-d5+',
#  'Qb5-d5#',
#  'Qb5xd5',
#  'Qb5xd5+',
#  'Qb5xd5#',
#  'Qf6-f8',
#  'Qf6-f8+',
#  'Qf6-f8#',
#  'Qf6xf8',
#  'Qf6xf8+',
#  'Qf6xf8#',
#  'Qf6-d6',
#  'Qf6-d6+',
#  'Qf6-d6#',
#  'Qf6xd6',
#  'Qf6xd6+',
#  'Qf6xd6#',
#  'Qh2-h1',
#  'Qh2-h1+',
#  'Qh2-h1#',
#  'Qh2xh1',
#  'Qh2xh1+',
#  'Qh2xh1#',
#  'Qb7-b6',
#  'Qb7-b6+',
#  'Qb7-b6#',
#  'Qb7xb6',
#  ...]

# %%
len(all_moves)
# Out:
# 23250

# %%
with open("moves.txt", 'w') as movef:
    for move in all_moves:
        movef.write(move + "\n")

# %%
tokens =  all_moves
special_tokens = ["<w>", "<b>", "<eos>"]

# %%
from transformers import Tokenizer

# %%
tokenizer = Tokenizer(models.WordLevel(unk_token="<unk>"))
tokenizer.add_special_tokens(tokens)
# Out:
# 23250

# %%
vocab = tokenizer.get_vocab()
vocab
# Out:
# {'Rb2xb6#': 5201,
#  'Qa5xb6+': 4192,
#  'Na3xb1': 13407,
#  'Rh8-h1': 14784,
#  'Kh5-h6#': 13688,
#  'Rc4-f4#': 11294,
#  'Rg1-g5+': 14851,
#  'c7-c8=B': 22464,
#  'Qg5xb5': 21069,
#  'Ka7-b6+': 9733,
#  'Kb4-a3': 11094,
#  'Qc4xe2#': 17723,
#  'Re6-e5': 7242,
#  'Qa7-a5#': 3920,
#  'Bg6-d3+': 8401,
#  'Qf7-a7': 10788,
#  'c2xb1=R+': 22951,
#  'Qd3xd4': 16521,
#  'Qg7xa7#': 5015,
#  'Ra8xg8+': 12976,
#  'g4xh5#': 23117,
#  'Rd6-d5+': 12871,
#  'Qd1xd5+': 17626,
#  'Qh3-e3': 9912,
#  'Rb8xf8#': 9197,
#  'Qd2xh2+': 15586,
#  'Qd7xd2': 4095,
#  'Ra5-a3': 888,
#  'Qc6-e8+': 12007,
#  'e2-e1=N#': 23060,
#  'Qg6-g5': 20712,
#  'Qa7-h7+': 6343,
#  'Bf1-d3+': 8395,
#  'f3-f2+': 22567,
#  'Qe4-e1': 6690,
#  'Qb4-b1#': 9674,
#  'Bh1xf3#': 20045,
#  'Ra4-a3': 10266,
#  'Kh3-g3#': 16004,
#  'Nf2-h3+': 19975,
#  'Ne3xf1': 20829,
#  'Qh1xa1': 4479,
#  'Qf7xe7': 1395,
#  'Qb1xb8#': 10601,
#  'Rg8xa8+': 14212,
#  'Qc2-d1': 17544,
#  'Kf8xe8+': 2344,
#  'Qa1-f6': 10962,
#  'Qh1-a1#': 4478,
#  'Rf7-g7+': 3721,
#  'Qh5xe8+': 15052,
#  'Qg6-f6#': 21110,
#  'Nd2xe4+': 1138,
#  'Rg1xf1': 16683,
#  'Qd6-d2': 5346,
#  'Bb6xd8#': 11681,
#  'Rf6xh6': 14253,
#  'Rd2xh2#': 17537,
#  'Rh2-h7': 5688,
#  'Qe7-g5#': 200,
#  'Kd8xe7#': 13049,
#  'Qd5-c5': 9726,
#  'Rc4-d4': 4890,
#  'Rh6-h1': 7764,
#  'Qf7-f8+': 19441,
#  'Re1xe8': 15153,
#  'Qe3-e1': 1932,
#  'Rc7xc2#': 11405,
#  'Nc5xd7+': 5146,
#  'Qc5-c6#': 11528,
#  'Qf8-f2+': 1957,
#  'Rh8-h3#': 14186,
#  'Ke8xf8+': 17332,
#  'Rd7xd1+': 2728,
#  'Rb8-f8+': 9193,
#  'Qg2xh2': 4563,
#  'Nd6xf5+': 15292,
#  'Qb4xc4': 15567,
#  'Qa1-a5#': 4064,
#  'Qh1xc6': 1863,
#  'Qh2xf2': 7785,
#  'd3-d2': 23166,
#  'Qh4xe1+': 7138,
#  'Bh7xd3': 8973,
#  'Qf8-f5+': 16825,
#  'Nf5xe3': 1149,
#  'Qe2xg4': 795,
#  'Qg2xa8+': 15532,
#  'Nd8xe6+': 15412,
#  'Qa8-b8+': 19099,
#  'Qe4-d4': 5136,
#  'Kb5-c6#': 80,
#  'Qa1xe1': 4635,
#  'Kd5xe6': 13371,
#  'Qf2xg3#': 7361,
#  'Kc1-b2': 11988,
#  'Bb8-d6+': 6925,
#  'Ke1xd2+': 13144,
#  'Qf7xc7': 3465,
#  'Qc6xa4+': 4468,
#  'Kf2xf3#': 9461,
#  'Bg5xd2#': 6761,
#  'Rh7xe7+': 14206,
#  'Qb6xf2': 15015,
#  'Qd8xf8#': 14483,
#  'Rb8xa8': 14865,
#  'Qc2xg2+': 16666,
#  'Nh2-f1#': 13856,
#  'Ba5-c3#': 16328,
#  'c2-c1=B#': 22679,
#  'Qc1-b2#': 21962,
#  'Re8xe5#': 917,
#  'Kf5xf4#': 12677,
#  'Qe3-h6': 18828,
#  'Qf8xf4': 141,
#  'c2xd1=N#': 23228,
#  'Kh7xg7': 17835,
#  'Qf2xg2+': 5260,
#  'Ke6-e7': 900,
#  'Bh3xf5': 4041,
#  'Ra8xe8#': 12575,
#  'Qc7-b8': 5988,
#  'Qd6-e7#': 13124,
#  'Qc5xb5+': 8470,
#  'Rh4-h5': 16464,
#  'f3xe2#': 22337,
#  'Qc7xf4#': 10757,
#  'Qg7xd7': 19827,
#  'Qb3xc4+': 7150,
#  'Qd2-d7': 17844,
#  'Qd8-d3#': 11192,
#  'Be5xb2+': 22006,
#  'Qc7-b7#': 13712,
#  'Re1xg1+': 2770,
#  'Rf8xe8+': 11536,
#  'Qe6xd5': 15033,
#  'Qh1-b1+': 16747,
#  'e2xf1=N+': 22354,
#  'Qd8xa8+': 1456,
#  'Rd4xd5+': 3304,
#  'Bb6xa5#': 10613,
#  'Rf8-d8#': 20612,
#  'Qc5xc8': 3117,
#  'Rb4-b3': 7554,
#  'Kc2xd3+': 8626,
#  'Qe1-h1': 8418,
#  'f5xg4#': 22508,
#  'Qb8xf4': 16269,
#  'Kd2-c2': 11334,
#  'Rf6-f3#': 4664,
#  'Qe3-e6+': 4417,
#  'Ra2xa8': 6681,
#  'Qh7-h4+': 5485,
#  'Qb2xb7': 17613,
#  'Bc5xb4': 9573,
#  'Qb3-b6': 15744,
#  'Qd3xa6#': 1373,
#  'Rf6xc6+': 2446,
#  'Kb4xa5': 21189,
#  'Rf5xe5': 2067,
#  'Qa2xf7': 12177,
#  'Qb1xb4+': 5248,
#  'Qe7-e1+': 12463,
#  'Re2-e8#': 14360,
#  'Rg5xf5#': 17999,
#  'Kh2xg2#': 7685,
#  'Bb3xd5+': 11176,
#  'Kc6-b7+': 10303,
#  'Ra5-h5+': 21649,
#  'Rh4-a4#': 1622,
#  'Qb4-a3': 17754,
#  'Bf2xg3#': 5915,
#  'Re3xe1': 3495,
#  'Kf6xe5': 12117,
#  'Qa3-c1': 12606,
#  'Qf4-g3#': 8384,
#  'Qf2xh2#': 10823,
#  'Kd8xe8': 7689,
#  'Qd7-d5+': 17191,
#  'Ng8-e7+': 4897,
#  'Qd2xh6': 14145,
#  'Kg8-f7+': 571,
#  'f4-f5': 23232,
#  'Rb8-b1': 7296,
#  'Bb5-d3': 11082,
#  'Kf6-e7+': 1039,
#  'Rg2xb2#': 6293,
#  'Re6xf6#': 11573,
#  'Kd7-e7#': 20228,
#  'Ke2xe3#': 10679,
#  'Rh3-h7': 10542,
#  'Bh7-d3': 8970,
#  'Kc3xc4+': 5518,
#  'Ba5xb6#': 3773,
#  'Bg1xa7': 21405,
#  'Rg4-g8+': 17425,
#  'Qa8xh1+': 1762,
#  'Rg3xb3': 6153,
#  'Qb2xb8': 1161,
#  'Qc1xg5': 9825,
#  'Qb1-g6': 19590,
#  'Nd4-c6#': 1262,
#  'Bf7xe8': 7209,
#  'Bh2xf4': 8925,
#  'Qa4-c2#': 2294,
#  'Bb2-c3+': 13489,
#  'Qd7-a7': 6258,
#  'Qc8-d8#': 5762,
#  'Ba2-c4': 12828,
#  'Qd8xd4+': 8242,
#  'Bf1xc4+': 20692,
#  'Qd5xe5#': 6497,
#  'Rc2-c6': 13512,
#  'Bc7-g3#': 18488,
#  'Kg5xf5+': 11728,
#  'Rh1-c1': 9738,
#  'Rc1xa1#': 4181,
#  'Kc3-b3+': 13129,
#  'Qa2xf7#': 12179,
#  'Qg1-d1': 17358,
#  'Rh3-h5': 9414,
#  'Qg4xb4#': 20141,
#  'Bf8-g7+': 9103,
#  'Be1-f2': 10866,
#  'Rf3-f5#': 2618,
#  'c7-c5#': 23195,
#  'Qf4-d4': 1572,
#  'Qh3xe6#': 12965,
#  'Na1xc2': 17385,
#  'Rc2-a2': 14988,
#  'Bc4xg8#': 4499,
#  'Qb2xf6': 21477,
#  'Bb6-a5+': 10609,
#  'Ne7xg6#': 7535,
#  'Qg3xb8+': 2290,
#  'Kf2xf1': 3099,
#  'Qh2xc2#': 7163,
#  'Qa3xb2+': 18322,
#  'Rb1-b8': 7440,
#  'Qh6-d6#': 17816,
#  'Rh3-c3#': 1928,
#  'Qe3-e6#': 4418,
#  'Ng5-f7+': 21553,
#  'Kf6-f5+': 18061,
#  'Bd3-f1#': 5540,
#  'Kc1xc2#': 19391,
#  'Qe3xg1#': 21737,
#  'Ke8xe7#': 13787,
#  'Be1-h4+': 13381,
#  'Qh3-h6#': 17102,
#  'Nf7-d6#': 11762,
#  'Bb7xa8#': 3329,
#  'Rf6xf7': 13911,
#  'Kg3-g2+': 10561,
#  'Qe6xc6+': 19810,
#  'Kg5-g4+': 15523,
#  'Qa1xg1+': 8722,
#  'Re5xc5': 4917,
#  'Qc5-b4+': 14623,
#  'Bf6-g5+': 6283,
#  'Bf8xc5#': 21053,
#  'Rh8xh3': 14187,
#  'Qg1xf2#': 15317,
#  'c7-c8=N+': 22444,
#  'Qh7xa7#': 21755,
#  'Qh3xe3': 9915,
#  'Bb4-d2': 5034,
#  'Qb1-h7+': 73,
#  'Rh6-h8#': 14492,
#  'Ra4-c4#': 5414,
#  'Re3-e1#': 3494,
#  'Rd6xd4#': 14951,
#  'Nd1-e3#': 15980,
#  'Rf6xa6#': 15371,
#  'Rf2-g2': 18594,
#  'Rh6-a6': 17310,
#  'Kh6-h7': 2046,
#  'c4-c5': 22977,
#  'Qa6xa1+': 10090,
#  'Qc4-c3+': 21331,
#  'Rd2-b2#': 6554,
#  'Qa7xg1#': 15191,
#  'Ba4-e8': 8868,
#  'Rb3xb7': 14451,
#  'Qc6xa8#': 15083,
#  'Qf1-d3': 2994,
#  'Qb5xc6+': 18682,
#  'Qb5-d5': 972,
#  'Kf3-f2': 1962,
#  'Qc4-c5#': 6302,
#  'Rf3xd3#': 2375,
#  'Rh4-b4': 2472,
#  'Ba1xc3': 20589,
#  'Rb4-d4#': 3764,
#  'Ra6-a5#': 11162,
#  'Rf4xg4+': 18112,
#  'Nf7xd6+': 11764,
#  'Bf4-e5+': 5563,
#  'Ba3xd6#': 6329,
#  'Bc3-b4+': 1639,
#  'Kf8-e7+': 8005,
#  'Re2-d2+': 17797,
#  'Ra1-b1#': 104,
#  'd7-d8=Q': 22185,
#  'Qd4-b6+': 8113,
#  'Qh6-a6': 9714,
#  'Nc6xa5': 16083,
#  'Qe8-b8#': 9236,
#  'Qc5-f2#': 308,
#  'Be6xg4+': 13768,
#  'Rd1xh1+': 21340,
#  'Qh3xf3#': 21485,
#  'Qd1xd4#': 9761,
#  'Kg1-h2': 15318,
#  'Re7xe6+': 14800,
#  'Be7-h4+': 18655,
#  'Re8-g8#': 3548,
#  'Qh4xf6+': 20950,
#  'Ra3-a1+': 649,
#  'Qg1-f1+': 13033,
#  'Qe4-e7#': 21254,
#  'Qd6xe6': 255,
#  'Qg7xe5+': 18610,
#  'Bg4xd1#': 14945,
#  'Ra8xf8#': 10787,
#  'Ne8xg7+': 12100,
#  'Bg4xf5+': 18394,
#  'Qd2-c2+': 20113,
#  'Kf3xe4+': 21688,
#  'Rg5-c5': 18906,
#  'Qh1-g1#': 3422,
#  'Ra3-a2+': 4753,
#  'Bf2-g1': 5706,
#  'c5xd6+': 22204,
#  'Bc8xf5+': 11632,
#  'Nf7-e5': 15444,
#  'Nf7-d8': 6000,
#  'Bb8xc7+': 6910,
#  'Qh7xh2+': 16942,
#  'Qd7-f7#': 21320,
#  'Bf7xe8+': 7210,
#  'Be4-a8#': 2018,
#  'Qd2xd1': 17337,
#  'Ka1-a2#': 18134,
#  'Bb4xd6#': 18971,
#  'Qd2xc1#': 19001,
#  'c3xd2#': 23165,
#  'c2xb1=B': 22422,
#  'Kd5xc5': 1605,
#  'Rb5-b4': 19278,
#  'Qc2xd1#': 17549,
#  'Bd2-g5+': 5869,
#  'Ra8xh8#': 6905,
#  'Rh8-h7#': 21776,
#  'Rc5xd5+': 18574,
#  'Rf1xf6+': 19006,
#  'Qa5-e1+': 15307,
#  'Rh2-a2': 17658,
#  'Kd7xd6+': 20236,
#  'Qe7-c7+': 18415,
#  'Qg4-f4#': 8030,
#  'Kg5-f6#': 13112,
#  'Qf3xe3+': 8080,
#  'Kf6xf5+': 18064,
#  'Qa4xc2#': 2297,
#  'Qf1-e1#': 19124,
#  'Rb3-b4': 12204,
#  'Qe8xb5': 6933,
#  'Kg5xf4+': 17458,
#  'Bb5xe8': 20385,
#  'Bc1xh6': 13497,
#  'd4-d5#': 22037,
#  'Rg7xg8#': 16199,
#  'Kf3xf4': 3237,
#  'Bf1-g2': 462,
#  'Rf5xb5#': 14171,
#  'Ra3-c3': 1470,
#  'Qd4-e4#': 15992,
#  'Kb2-c3#': 2780,
#  'Qa7-c5#': 3980,
#  'Qh5xh8#': 11081,
#  'Bd3xg6': 18807,
#  'Qc3-g7+': 10273,
#  'Rg3-e3+': 3643,
#  'Rg5-e5': 168,
#  'Qg2-g4': 18366,
#  'Bh1-a8#': 4718,
#  'Ka3xa2': 10737,
#  'Qh5xg5+': 10558,
#  'Qc6-f3+': 10687,
#  'Qf7xg8#': 16625,
#  'd7xc8=N+': 22435,
#  'Rc7-c3+': 5395,
#  'Kh1xh2#': 3485,
#  'Nf5-h6': 7986,
#  'Qh7xg7#': 14639,
#  'Qh8-c8': 8928,
#  'Qe6xe2#': 19949,
#  'Qc1xd1#': 15779,
#  'Qb2xe5+': 7372,
#  'Rg1-g4+': 7801,
#  'Bc7xe5+': 3598,
#  'c5xb6+': 22726,
#  'Ne6xc7': 10317,
#  'Qh8-h4+': 13819,
#  'Qe5-a5#': 2882,
#  'Kb3-a3#': 9932,
#  'Qe2xe3#': 12695,
#  'Qb8xc8#': 6617,
#  'Qg2xb2#': 7517,
#  'Rh6xc6+': 1846,
#  'Kf3-f2#': 1964,
#  'Qc5xe7': 2787,
#  'Qc3-c6#': 12734,
#  'Nd2xf1#': 17141,
#  'Na6xc7+': 21574,
#  'Qb2xh8': 14223,
#  'Re6-h6+': 12439,
#  'Rg5xg6+': 5314,
#  'Qb2-f2+': 18931,
#  'Qa5xb5#': 353,
#  'Rb3-b1': 11850,
#  'Bb3-a2': 9564,
#  'Qd8xa8#': 1457,
#  'Bd3xf5#': 15137,
#  'Qa6-f1+': 21289,
#  'Qe5-e6+': 19285,
#  'Rd4xe4#': 14903,
#  'Qa6xd3': 11733,
#  'Qf2xf7': 3453,
#  'Rg2xh2': 13605,
#  'Rg7xf7#': 1295,
#  'Bc1-b2': 21324,
#  'Ne6xg5+': 15796,
#  'Kg4xh4#': 15599,
#  'Rf8-b8#': 6806,
#  'Rb7-d7': 21594,
#  'Qh4xe1': 7137,
#  'Ng6-h8+': 8605,
#  'Bg5-e3': 11796,
#  'Bd7xe8': 20439,
#  'Qh8xh5#': 1973,
#  'Bg7-b2+': 17353,
#  'Kd4-e5': 696,
#  'Rg5xd5': 21441,
#  'Bf8-c5#': 21050,
#  'Qe2-g2#': 11414,
#  'Qf8xf3': 12243,
#  'Qh4-h5+': 15253,
#  'Rh2xh1': 15225,
#  'Qc2-c6#': 4808,
#  'Qe7xf6#': 16541,
#  'Nf6xh5': 16701,
#  'Bg3xf4#': 3629,
#  'Bc5xe7+': 7492,
#  'Qh6-d6': 17814,
#  'Kb8xc8+': 18094,
#  'Kd8xd7+': 7336,
#  'Ne7xc8#': 7985,
#  'Bg6-h5#': 11006,
#  'Re3-e1': 3492,
#  'Ng6-e5': 18444,
#  'Qf2xf8+': 17116,
#  'Rf4-e4': 11262,
#  'Qb1xf5+': 1438,
#  'Nb6-a8+': 7651,
#  'Rb4-g4': 19014,
#  'Rf5xf2': 2139,
#  'Qe6xd7#': 7733,
#  'Qc7-a5#': 12434,
#  'Qb1xe4+': 5662,
#  'Rh1-a1#': 15332,
#  'Rd8-d3#': 15728,
#  'Ra1-a3#': 13226,
#  'Qg8-d8#': 16028,
#  'Qe7xd8#': 13259,
#  'Rd5xh5': 17715,
#  'Qa6xf1+': 21292,
#  'Be3-g5#': 18236,
#  'Qc1xa3+': 13186,
#  'Qg6xg3#': 6065,
#  'Ng6-h8': 8604,
#  'Nc7-a6': 12474,
#  'Qh6-d2#': 5462,
#  'Qg3xa3': 9537,
#  'Rf6-f2': 9540,
#  'Ra8-a4': 12768,
#  'Nb4xc6': 10779,
#  'Qb3xb7': 4821,
#  'Qc1xb2#': 21965,
#  'Qc6-e4': 13266,
#  'Rg1xg5': 14853,
#  'Qe5xc5#': 17465,
#  'Rc2xc4#': 15713,
#  'Qf4xf2': 21717,
#  'Kc5-b4': 19410,
#  'Qa4-h4': 132,
#  'Rh8-b8#': 1550,
#  'b2-b4#': 23027,
#  'Nh2xf1+': 13858,
#  'Bf5xc8': 2409,
#  'Rd5-d4+': 15925,
#  'Re7xa7+': 11554,
#  'Bg1-b6+': 9517,
#  'Ng6-e5#': 18446,
#  'Qe6-b3': 3438,
#  'Kb7-c8#': 8354,
#  'Qe7-c7': 18414,
#  'Qb3xb4#': 5195,
#  'Bb7xc8': 9135,
#  'Qa7xe3': 16719,
#  'Qh6-h3+': 3475,
#  'Nc7xa8#': 16649,
#  'Bd3xh7#': 11507,
#  'Kg7xh6#': 16013,
#  'Rg7-c7+': 18295,
#  'Bb1-c2#': 10550,
#  'Qf5-d3+': 18913,
#  'g6xh5#': 22196,
#  'Qe2xf3#': 8369,
#  'Kb3-a2+': 3133,
#  'Ng5-e4': 18702,
#  'Ra6-f6': 8406,
#  'Bd4-g7': 16992,
#  'Rb2-d2+': 10615,
#  'Rh8-h7': 21774,
#  'Ka2-b3+': 11815,
#  'Qd3-d8#': 9554,
#  'Kg4xh4+': 15598,
#  'Bc2-b3#': 5150,
#  'e7xd6+': 22798,
#  'Qf4xc7': 20685,
#  'Kf3-g2': 10428,
#  'Rb5-h5#': 10322,
#  'Rc6xb6#': 16019,
#  'Bb4xc5': 14571,
#  'Bg3-c7#': 11498,
#  'Rb8xc8#': 4553,
#  'Kd4xd3#': 17711,
#  'Kc4-d4#': 5786,
#  'c3-c2': 22635,
#  'Qb8xd6#': 10901,
#  'Qa6-a2#': 12080,
#  'Qh7-f5': 90,
#  'Bh8xd4#': 8549,
#  'Qh6-h7+': 14119,
#  'Bg2xb7': 18039,
#  'Bb2-h8+': 16855,
#  'Qd1xb3': 8733,
#  'Rh8xb8+': 1552,
#  'b6-b7': 22104,
#  'Rh1-h2': 4734,
#  'Rf4-f7': 13446,
#  'Be4xg6+': 13054,
#  'Rc5xc3': 21843,
#  'Rc4-c3': 21924,
#  'Bb3-f7': 10854,
#  'Re7-c7#': 12110,
#  'Rd8-h8+': 19873,
#  'Rb7-b4#': 7058,
#  'Rh6-f6#': 5948,
#  'Qe7xe8': 13635,
#  'Rc2xc3': 3201,
#  'Qf5xg5#': 551,
#  'Qd4xe5': 2955,
#  'Re5-h5': 11442,
#  'Kb4-c3': 12678,
#  'Kb7xc6#': 13097,
#  'Qg8xd8': 16029,
#  'Qh3xh1#': 647,
#  'Bf3xg4#': 21623,
#  'Rc3xc2+': 10486,
#  'Qf5xc2+': 13330,
#  'Qg5xg3#': 7397,
#  'e7-e8=Q': 22026,
#  'Bb3-c4': 5862,
#  'Qe3xe8#': 8297,
#  'Qb3-b8+': 14131,
#  'Kf3xg2#': 10433,
#  'a5xb6': 22371,
#  'f5xe4+': 22462,
#  'Qf4-f8#': 10646,
#  'Bf5-c2#': 4130,
#  'g2xf1=R#': 22994,
#  'Nh7xf6': 6969,
#  'Qd4xh4': 9369,
#  'Qf2-h2+': 10819,
#  'Qf2-d2+': 16381,
#  'Qh5-f5': 12624,
#  'Qd7-f5#': 17264,
#  'Qe7xd7#': 12413,
#  'Rf8xg8+': 3028,
#  'Re2-b2+': 20881,
#  'Bf2-b6+': 2395,
#  'Kf5-e4#': 1142,
#  'Qe8-a4': 3834,
#  'Qe7xe4+': 12652,
#  'Bd5-e4#': 3998,
#  'Rf6-d6': 4146,
#  'Rd1xd2': 16713,
#  'Bd1-h5#': 13040,
#  'Qd8xh4': 14037,
#  'Nc4xa5+': 2032,
#  'Qg2-a2+': 2185,
#  'Qf1-f8': 15738,
#  'Ra4xa8#': 18569,
#  'Qd1xc2': 3105,
#  'Qf2-b2#': 15428,
#  'Qg6xh5': 11607,
#  'Qc2-b3': 8772,
#  'Nb6-a4': 456,
#  'Nf6xg8+': 11842,
#  'Na2xc3#': 11513,
#  'Qa2-c2+': 16051,
#  'Kc7xd8+': 14266,
#  'Qd6-c7': 7566,
#  'Ra3xa1#': 653,
#  'Qe5xh2+': 4300,
#  'Kc4xd5': 411,
#  'Bc7xf4': 8829,
#  'Bc6xf3#': 20771,
#  'Be4xd3+': 16114,
#  'Qh1-d1#': 21158,
#  'Qa7xf7#': 10943,
#  'Qa8xd8#': 17981,
#  'Qf3-a8': 12426,
#  'Qd4-b4+': 10333,
#  'Bg3xh2#': 12311,
#  'Bb6xe3': 15963,
#  'Rd1xd4+': 12298,
#  'Re1-e8+': 15151,
#  'Qf8xf3#': 12245,
#  'Ra1-a2#': 20462,
#  'Qb3xb6+': 15748,
#  'Bc1xf4+': 13156,
#  'Ng6-f8+': 14761,
#  'Qg5-e7': 13746,
#  'Re1xg1#': 2771,
#  'Qe1-e2': 21162,
#  'Rf6xc6': 2445,
#  'Kb5-b6': 2022,
#  'Rf4xf8#': 7781,
#  'Nd3-b4+': 3751,
#  'Rb3-b8+': 8377,
#  'c2xd1=B+': 22417,
#  'Kg5xh5#': 8597,
#  'Bf6-g7#': 13388,
#  'Qh1xh5': 2427,
#  'Qe6xa6': 18375,
#  'Rc2-c5': 4428,
#  'Qb2-b3': 6360,
#  'f6-f7': 22200,
#  'Rg8xh8#': 5513,
#  'Rh6xf6#': 5951,
#  'Rd2-d6+': 2695,
#  'Ke3-f4#': 13508,
#  'Kg3-f4': 11136,
#  'Rh2-h8': 10374,
#  'Rb4xf4#': 3353,
#  'Kh4xh3': 951,
#  'Bc6xb7#': 11885,
#  'Bf5-e6#': 12050,
#  'Qe5xa1#': 16847,
#  'Qa3-a7+': 2713,
#  'Bc4-a2+': 14953,
#  'Rf6xf1+': 7792,
#  'Ra5-h5': 21648,
#  'Be4xa8+': 2020,
#  'Rf8xf2': 14823,
#  'Rc7-c2#': 11402,
#  'Rd7xd8#': 7871,
#  'Na6-c7': 21570,
#  'Qc2xc8#': 17279,
#  'Qe3xe8+': 8296,
#  'Kc6-b6+': 2539,
#  'Bd5xc4#': 6545,
#  'Kd7xd8': 21015,
#  'Rd6xe6+': 13336,
#  'Rc2-c1': 10044,
#  'Kb1-b2+': 8311,
#  'Qa1-h1+': 17953,
#  'Rb3xb2#': 4283,
#  'Rb3-c3#': 11768,
#  'Bh7xg6+': 16576,
#  'Qh1xb1#': 16751,
#  'Qf7xh5': 13455,
#  'Ra1xg1+': 12076,
#  'd5xe6': 22020,
#  'Qd7xg7': 11937,
#  'Qg5xb5#': 21071,
#  'Rf4-f1': 14916,
#  'Nd4xe6': 2367,
#  'Qh2-h6': 12456,
#  'Na8-c7+': 16159,
#  'Bg4xc8#': 20819,
#  'Qc7xg3+': 18868,
#  'Qf7xg6': 2877,
#  'Qd3-f3+': 4801,
#  'Re5-b5': 12900,
#  'Ba4-d1#': 19046,
#  'Qe3xd3': 14313,
#  'Rd5-d3#': 12140,
#  'Bc6xb7': 11883,
#  'Qa6xa7#': 9869,
#  'Rh1-h5#': 13430,
#  'Rc2xd2+': 7696,
#  'Bf4-c1+': 8599,
#  'Qb6-c6': 10992,
#  'Qc8-f8#': 1004,
#  'Kd8-d7#': 7334,
#  'Kd7-c8': 516,
#  'Rb5xg5+': 5572,
#  'Qh5-h4+': 745,
#  'Kb7-c6+': 13093,
#  'Qg2xd5#': 2759,
#  'Qc4-c8': 13998,
#  'Bd5-a8+': 2965,
#  'Rh4-d4': 10248,
#  'Rd2-h2+': 17533,
#  'Kg2-g1': 18840,
#  'Qc1-f1': 7020,
#  'Rf2xg2': 18597,
#  'Kh1-g2#': 9482,
#  'Qh6xg6': 9375,
#  'Ba4-e8+': 8869,
#  'Ng2xe1#': 875,
#  'Rb6-g6+': 4867,
#  'e4xd5': 22482,
#  'Bd2xa5': 2313,
#  'Nb6xa8': 7653,
#  'Ba4xb3#': 14105,
#  'd2xc1=N#': 23063,
#  'Qd6xa6#': 19325,
#  'Bc3-f6': 16578,
#  'Be8xc6': 19989,
#  'Qe2-a2+': 2401,
#  'Bd2xe3+': 16132,
#  'Qf6xc6+': 1258,
#  'Qc3-f6': 8022,
#  'Qd1xf1#': 5849,
#  'Qf1-g2#': 5120,
#  'Be2-d1+': 17233,
#  'Qf2xa7#': 13463,
#  'Qc8-d7#': 19058,
#  'Be6xd7#': 5321,
#  'Rd8-e8': 15390,
#  'Bc5-e7': 7488,
#  'Kh5xg4#': 15767,
#  'Rg5xg8': 11181,
#  'Rb8-b4': 18216,
#  'Bc4-d3': 11574,
#  'Kf5xg4': 9165,
#  'Rb3xg3+': 21316,
#  'Qe7xa7+': 8758,
#  'Kd7-d8+': 21013,
#  'Kh2-h1#': 6350,
#  'Kh6-g7': 780,
#  'Qh3-f3+': 21481,
#  'Kc7xd8': 14265,
#  'Qb6xd8+': 8980,
#  'Qg2xe2#': 10517,
#  'Qg8xg1+': 18334,
#  'd7-d5': 22326,
#  'Qe1-e5+': 17905,
#  'Kc2xd2+': 17830,
#  'Qe4xa8+': 1444,
#  'Rd1-d7#': 6446,
#  'Qc4-d3#': 13004,
#  'Qa6-h6+': 16531,
#  'Rg3-g2': 17778,
#  'Nd5-b4#': 16418,
#  'Rd2xe2': 16893,
#  'Kd5xc4#': 11387,
#  'Rf4xh4+': 17188,
#  'Qb4-h4': 8658,
#  'Qb3-c4+': 7147,
#  'Kf4xf3': 18165,
#  'Qe2xc2+': 13684,
#  'Qb6xf2#': 15017,
#  'Rh7xh2': 9693,
#  'Bf6xc3+': 3808,
#  'Rd1-f1#': 20396,
#  'd7xe8=N': 22008,
#  'Kb5-a6#': 16304,
#  'Qc6xc4': 16257,
#  'Na1xb3': 16071,
#  'Rg8-a8': 14208,
#  'Rb8xa8#': 14867,
#  'Qf3-d3': 17046,
#  'Kc2-d2+': 17827,
#  'Qg5xg8': 15477,
#  'Bf1xg2#': 467,
#  'Bc3-d2+': 4219,
#  'Qb3-b7+': 4819,
#  'Qa5-a7#': 15788,
#  'Qe6xf6': 2091,
#  'Ba1-h8': 7026,
#  'Qh1-d1+': 21157,
#  'Qa5xc5+': 8248,
#  'Nd6-b7+': 11977,
#  'Ka7-b6': 9732,
#  'Ba6-c8#': 11144,
#  'Bd6xb4': 20835,
#  'Bg2-d5': 10902,
#  'Qg3-f2': 840,
#  'Qe6xb6#': 8279,
#  'Rh3xh6': 20523,
#  'Qh1-f3+': 15895,
#  'Ne4-g3': 9786,
#  'Qb8-b7#': 14336,
#  'Rg5-g7': 16818,
#  'e3xf2#': 22052,
#  'Rb5-h5': 10320,
#  'Qh4-h3+': 2461,
#  'Qd5xg8+': 10348,
#  'e6-e7#': 23159,
#  'Rg8xh8+': 5512,
#  'Be8xh5': 10863,
#  'Ra5-a1#': 14012,
#  'Bd1-g4+': 18739,
#  'Qb4xe7': 20085,
#  'Re6xd6': 5073,
#  'Rh2-h3+': 5677,
#  'Nd6xe4#': 12227,
#  'Nd6-b5+': 3013,
#  'Bb1-f5': 7458,
#  'Qa6xa4+': 10990,
#  'Kd2xd1#': 19109,
#  'Be7-d6': 17646,
#  'Bb5-a4#': 1610,
#  'Be6-a2#': 19298,
#  'Bg5xf6': 18921,
#  'Qb2xc2#': 20333,
#  'Kg5xh4#': 791,
#  'Ra8xd8+': 19834,
#  'Qh8-f6': 20568,
#  'Rc1-c5+': 19117,
#  'Bf6-c3+': 3805,
#  'Qf5xe5+': 8068,
#  'Bg4-c8+': 20815,
#  'Kg2xf3+': 18352,
#  'Qh7-d7+': 607,
#  'Re5xe6': 17307,
#  'd7xe8=Q+': 22912,
#  'Rh4xb4#': 2477,
#  'Ka3xb2#': 15881,
#  'Qh6xd6': 17817,
#  'Rf6-c6#': 2444,
#  'Bh1xa8': 4719,
#  'a7xb8=B+': 22969,
#  'Rh4xc4#': 14531,
#  'Qe3-b6': 14238,
#  'Qg8xc4+': 16924,
#  'g4xf3': 22659,
#  'Qe2xb5': 11289,
#  'Qc7xb7': 13713,
#  'Qc5xf8': 2385,
#  'Qh7xe4+': 3256,
#  'Qf4-b8': 13308,
#  'Qf7xe6': 4845,
#  'Qf6-h8#': 14684,
#  'Qf7-f3+': 12121,
#  'Kf2xf3+': 9460,
#  'Qd1-d6': 8766,
#  'Kc8xb8#': 4349,
#  'Rb6xb4': 19923,
#  'Rf4xa4#': 2711,
#  'Ke3-d2#': 3212,
#  'Nc8-a7': 19722,
#  'Rg2-e2#': 6014,
#  'Nc3-d5+': 9091,
#  'Qa8xd5+': 20722,
#  'Rd6xb6#': 10289,
#  'Qg4-g7+': 835,
#  'Qg8xg3+': 18388,
#  'Nc5-d3#': 19916,
#  'Ng2xf4+': 14662,
#  'g7xf8=R': 22887,
#  'Qc2xe4': 9897,
#  'Qb6-b2': 708,
#  'Bd3-a6+': 1849,
#  'Bf6-e5': 6252,
#  'Qb5xb6': 2745,
#  'Bd2xg5#': 5873,
#  'Qh1xh8+': 18130,
#  'Kd8xc8': 13443,
#  'Re7xf7': 1923,
#  'Rh6xc6': 1845,
#  'Ke5xe4': 5433,
#  'Rf8-h8+': 15607,
#  'Re4-e2+': 13873,
#  'Qg7-c7+': 7831,
#  'Nd8xf7+': 20218,
#  'Bf2xa7': 435,
#  'Qb5-d5#': 974,
#  'Qc4-a4+': 8791,
#  'Rf5-f6#': 16436,
#  'Qf4xd2+': 3610,
#  'Rg7-g5': 11196,
#  'Qd4xf4+': 6094,
#  'Rb8-f8': 9192,
#  'Bd3xc2': 16545,
#  'Rc3-c2': 10482,
#  'Rb6-b5': 20088,
#  'Rc3-c4#': 13010,
#  'Qc5xb6+': 8938,
#  'Rh8xc8': 19233,
#  'Qb2-b3#': 6362,
#  'Rg1-e1': 13770,
#  'Bd8xe7#': 11225,
#  'Kc3-c2+': 8581,
#  'Rc6-c3+': 6871,
#  'Re8xe7': 17793,
#  'Rb5-b8#': 12002,
#  'Rd2xd4+': 802,
#  'Re1xa1': 315,
#  'Qh7xc2+': 5602,
#  'Nd4-f3#': 12494,
#  'Kg2xf3': 18351,
#  'Ba5xc7#': 4031,
#  'Bd2xe1+': 18952,
#  'Qa7xa6': 16461,
#  'Qa2xc2+': 16054,
#  'Rh4-h1': 4542,
#  'Rg8-e8#': 8264,
#  'Bh6xc1#': 9725,
#  'Kh4-h3': 948,
#  'Bd6-c7#': 14306,
#  'Rh3xa3+': 14986,
#  'Rg8-g5+': 15733,
#  'Bd7-c8+': 12313,
#  'Qe8xa4+': 3838,
#  'Qh8xe8': 5493,
#  'Rh8xa8#': 21503,
#  'Qg5-h4+': 4927,
#  'Ke6xe7': 903,
#  'Qe1-h4+': 15379,
#  'Qa3-a5#': 5636,
#  'Qa1xa6+': 12280,
#  'Qd2xb4+': 6166,
#  'Kb2xa3+': 18172,
#  'Rg5-e5#': 170,
#  'Kh6xh5#': 6515,
#  'Bg2-d5+': 10903,
#  'Qh2-e5+': 9859,
#  'Bh5xf7': 4677,
#  'Qc3-c2': 14508,
#  'Re2-h2#': 812,
#  'Bg4-d1#': 14942,
#  'Qc3-c4#': 9446,
#  'Qe1xe3+': 1996,
#  'Kb6-c6#': 2504,
#  'Qc3xg3#': 15275,
#  'Ba3xb4': 17367,
#  'Rc6xc2': 17823,
#  'Bb7xd5+': 13546,
#  'Ba3-d6': 6324,
#  'Nd7xf8#': 18653,
#  'Qc4xd3': 13005,
#  'Kg7xh7+': 1660,
#  'g5xf4+': 22270,
#  'Ne4xf6#': 9359,
#  'Qa3-a2#': 1100,
#  'Qf4xh4#': 1637,
#  'Bd4xc5#': 13829,
#  'Ra5-h5#': 21650,
#  'Qg5xe3': 4851,
#  'Rg3-g1+': 9961,
#  'Rh7xe7': 14205,
#  'Ra5xc5#': 10445,
#  'Bh5-g4': 17478,
#  'Rh4xh5': 16467,
#  'Rc1-e1+': 1789,
#  'Kb5-b4': 3726,
#  'Nd5-f6+': 6643,
#  'Rb4xb8+': 6460,
#  'Qb7-b5#': 7232,
#  'Bd1-f3+': 18301,
#  'Qe4-e1#': 6692,
#  'Nb5-a7': 7092,
#  'Ra2-d2+': 19129,
#  'Ke6-f6+': 10183,
#  'Qe5-g3#': 11000,
#  'Bb5-f1#': 13574,
#  'Rh3xb3#': 13349,
#  'Nf3xd4+': 10954,
#  'Rc7xc4': 5757,
#  'Qh6-g7': 1206,
#  'Qc5-h5#': 16838,
#  'Bh1xd5#': 14831,
#  'Qb6xc5#': 18251,
#  'Bc4-a6': 5436,
#  'Qf1-e1+': 19123,
#  'Rh1xa1#': 15335,
#  'Qg3-h3#': 1130,
#  'Ke1xe2': 11271,
#  'Bg5xh4+': 4618,
#  'Qb4-e7+': 20083,
#  'Qb1-g1': 6894,
#  'Qe2-f3#': 8366,
#  ...}

# %%
import json

with open("vocab.json", 'w') as outfile:
    json.dump(vocab, outfile)

# %%
tokenizer = Tokenizer(models.WordLevel(vocab=vocab, unk_token="<unk>"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /data/evan/CS285_Final_Project/create_tokenizer.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell://tunnel%2Bjiaolab-cluster/data/evan/CS285_Final_Project/create_tokenizer.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> tokenizer = Tokenizer(models.WordLevel(vocab=vocab, unk_token="<unk>"), special_tokens=special_tokens)
#
# TypeError: Tokenizer.__new__() got an unexpected keyword argument 'special_tokens'

# %%
tokenizer.add_special_tokens(special_tokens)
# Out:
# 3

# %%
tokenizer.save("model/tokenizer.model")

# %%
tokenizer = tokenizer.from_file("model/tokenizer.model")

# %%
tokenizer.encode("O-O<eos>").ids
# Out:
# [23244, 23252]
